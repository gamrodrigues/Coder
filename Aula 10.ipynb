# %% [markdown]
# Pandas parte II

# %%
#Bibliotecas
import pandas as pd
import numpy as np

# %%
#Base de dados
casas= pd.read_csv('Dataset - Preço de Casas.csv', sep=' ', encoding='latin1', decimal=',')
casas
# Out:
#        Pés²  Quartos  Banheiros Vizinhança  AnoConstrução       Preço($)
# 0      2126        4          1      Rural           1969  215355.283618
# 1      2459        3          2      Rural           1980  195014.221626
# 2      1860        2          1   Subúrbio           1970  306891.012076
# 3      2294        2          1     Urbano           1996  206786.787153
# 4      2130        5          2   Subúrbio           2001  272436.239065
# ...     ...      ...        ...        ...            ...            ...
# 49995  1282        5          3      Rural           1975  100080.865895
# 49996  2854        2          2   Subúrbio           1988  374507.656727
# 49997  2979        5          3   Subúrbio           1962  384110.555590
# 49998  2596        5          2      Rural           1984  380512.685957
# 49999  1572        5          3      Rural           2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
casas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Pés²           50000 non-null  int64
#  1   Quartos        50000 non-null  int64
#  2   Banheiros      50000 non-null  int64
#  3   Vizinhança     50000 non-null  object
#  4   AnoConstrução  50000 non-null  int64
#  5   Preço($)       50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
#funções de agregação

print('Contagem:',casas['Preço($)'].count())
print('Soma:',casas['Preço($)'].sum())
print('Média:',casas['Preço($)'].mean())
print('Mínimo:',casas['Preço($)'].min())
print('Máximo:',casas['Preço($)'].max())
print('Mediana:',casas['Preço($)'].median())
print('Quantil 0%:',casas['Preço($)'].quantile(0))
print('Quantil 25%:',casas['Preço($)'].quantile(0.25))
print('Quantil ?%:',casas['Preço($)'].quantile())
print('Quantil 50%:',casas['Preço($)'].quantile(0.5))
print('Quantil 75%:',casas['Preço($)'].quantile(0.75))
print('Quantil 100%:',casas['Preço($)'].quantile(1))
print('Desvio-padrão:',casas['Preço($)'].std())
print('Variância:',casas['Preço($)'].var())
# Out:
# Contagem: 50000
# Soma: 11241903545.01902
# Média: 224838.0709003804
# Mínimo: 154.77912007166017
# Máximo: 492195.2599720151
# Mediana: 225052.14116600397
# Quantil 0%: 154.77912007166017
# Quantil 25%: 169955.8602251014
# Quantil ?%: 225052.14116600397
# Quantil 50%: 225052.14116600397
# Quantil 75%: 279373.6300523317
# Quantil 100%: 492195.2599720151
# Desvio-padrão: 76110.10551805237
# Variância: 5792748161.969065

# %%
casas.describe(include='all')
# Out:
#                 Pés²       Quartos     Banheiros Vizinhança  AnoConstrução  \
# count   50000.000000  50000.000000  50000.000000      50000   50000.000000
# unique           NaN           NaN           NaN          3            NaN
# top              NaN           NaN           NaN   Subúrbio            NaN
# freq             NaN           NaN           NaN      16721            NaN
# mean     2006.374680      3.498700      1.995420        NaN    1985.404420
# std       575.513241      1.116326      0.815851        NaN      20.719377
# min      1000.000000      2.000000      1.000000        NaN    1950.000000
# 25%      1513.000000      3.000000      1.000000        NaN    1967.000000
# 50%      2007.000000      3.000000      2.000000        NaN    1985.000000
# 75%      2506.000000      4.000000      3.000000        NaN    2003.000000
# max      2999.000000      5.000000      3.000000        NaN    2021.000000
#
#              Preço($)
# count    50000.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    224838.070900
# std      76110.105518
# min        154.779120
# 25%     169955.860225
# 50%     225052.141166
# 75%     279373.630052
# max     492195.259972

# %%
casas_str=casas.copy()
casas_str['Quartos']=casas_str['Quartos'].astype(str)
casas_str['Banheiros']=casas_str['Banheiros'].astype(str)
casas_str.describe(include='all')
# Out:
#                 Pés² Quartos Banheiros Vizinhança  AnoConstrução  \
# count   50000.000000   50000     50000      50000   50000.000000
# unique           NaN       4         3          3            NaN
# top              NaN       3         1   Subúrbio            NaN
# freq             NaN   12661     16755      16721            NaN
# mean     2006.374680     NaN       NaN        NaN    1985.404420
# std       575.513241     NaN       NaN        NaN      20.719377
# min      1000.000000     NaN       NaN        NaN    1950.000000
# 25%      1513.000000     NaN       NaN        NaN    1967.000000
# 50%      2007.000000     NaN       NaN        NaN    1985.000000
# 75%      2506.000000     NaN       NaN        NaN    2003.000000
# max      2999.000000     NaN       NaN        NaN    2021.000000
#
#              Preço($)
# count    50000.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean    224838.070900
# std      76110.105518
# min        154.779120
# 25%     169955.860225
# 50%     225052.141166
# 75%     279373.630052
# max     492195.259972

# %%
#group by
#df.groupby('coluna string para agregar')[['variáveis quantitativas']].'função de agregação'
casas.groupby('Vizinhança')[['Preço($)']].mean()
# Out:
#                  Preço($)
# Vizinhança
# Rural       224107.499993
# Subúrbio    223238.199695
# Urbano      227183.095707

# %%
casas.groupby('Vizinhança')[['Quartos','Banheiros']].mean()
# Out:
#              Quartos  Banheiros
# Vizinhança
# Rural       3.506836   1.991185
# Subúrbio    3.493930   2.000658
# Urbano      3.495332   1.994399

# %%
casas.groupby('Vizinhança')[['Preço($)']].sum()/1000000
# Out:
#                Preço($)
# Vizinhança
# Rural       3737.216670
# Subúrbio    3732.765937
# Urbano      3771.920938

# %%
casas.groupby('Vizinhança')[['AnoConstrução']].min()
# Out:
#             AnoConstrução
# Vizinhança
# Rural                1950
# Subúrbio             1950
# Urbano               1950

# %%
casas.groupby('Vizinhança')[['AnoConstrução']].max()
# Out:
#             AnoConstrução
# Vizinhança
# Rural                2021
# Subúrbio             2021
# Urbano               2021

# %%
casas_str.groupby('Quartos')[['Preço($)']].max()
# Out:
#               Preço($)
# Quartos
# 2        470989.679074
# 3        468493.877841
# 4        462557.562958
# 5        492195.259972

# %%
casas_str.groupby('Banheiros')[['Preço($)']].mean()
# Out:
#                 Preço($)
# Banheiros
# 1          221975.512964
# 2          225305.469401
# 3          227267.438122

# %%
#group by agg

casas.groupby('Vizinhança').agg(['min', 'max', 'mean'])
# Out:
#             Pés²                    Quartos               Banheiros      \
#              min   max         mean     min max      mean       min max
# Vizinhança
# Rural       1000  2999  2001.621132       2   5  3.506836         1   3
# Subúrbio    1000  2999  2000.151127       2   5  3.493930         1   3
# Urbano      1000  2999  2017.416913       2   5  3.495332         1   3
#
#                      AnoConstrução                       Preço($)  \
#                 mean           min   max         mean         min
# Vizinhança
# Rural       1.991185          1950  2021  1985.353262  602.209099
# Subúrbio    2.000658          1950  2021  1985.515280  154.779120
# Urbano      1.994399          1950  2021  1985.344155  434.097124
#
#
#                       max           mean
# Vizinhança
# Rural       492195.259972  224107.499993
# Subúrbio    482577.163405  223238.199695
# Urbano      476671.733263  227183.095707

# %%
casas.sort_values(['AnoConstrução'])
# Out:
#        Pés²  Quartos  Banheiros Vizinhança  AnoConstrução       Preço($)
# 978    2727        4          2      Rural           1950  312734.662929
# 49613  2595        2          3      Rural           1950  322066.887052
# 47017  2351        5          1     Urbano           1950  209254.046525
# 30593  2062        2          1     Urbano           1950  210545.821380
# 30597  1210        3          3     Urbano           1950  236703.740681
# ...     ...      ...        ...        ...            ...            ...
# 5152   1792        2          1      Rural           2021  208535.141558
# 45884  2563        3          1      Rural           2021  309113.895190
# 5180   2478        2          3      Rural           2021  259451.915141
# 41824  1192        4          1      Rural           2021  184293.602423
# 48466  2594        4          3      Rural           2021  274836.546704
#
# [50000 rows x 6 columns]

# %%
#Ordenação
casas_ordenado=casas.sort_values(['Preço($)']).sort_values(['AnoConstrução','Pés²'], ascending=False).reset_index(drop=True).copy()
casas_ordenado
# Out:
#        Pés²  Quartos  Banheiros Vizinhança  AnoConstrução       Preço($)
# 0      2998        3          2     Urbano           2021  389877.561983
# 1      2997        5          2     Urbano           2021  307426.619635
# 2      2996        2          1     Urbano           2021  309039.902643
# 3      2996        4          2   Subúrbio           2021  327147.003024
# 4      2993        2          3   Subúrbio           2021  273396.072621
# ...     ...      ...        ...        ...            ...            ...
# 49995  1018        5          1      Rural           1950  196520.960758
# 49996  1017        2          1      Rural           1950   31952.189583
# 49997  1008        5          3   Subúrbio           1950  113430.700683
# 49998  1003        3          1   Subúrbio           1950   79561.868267
# 49999  1000        3          3     Urbano           1950  155023.910172
#
# [50000 rows x 6 columns]

# %%
casas.sort_values('AnoConstrução', ascending=False)
# Out:
#        Pés²  Quartos  Banheiros Vizinhança  AnoConstrução       Preço($)
# 14783  1343        4          2   Subúrbio           2021  132588.952146
# 20540  1366        3          1      Rural           2021  148245.087216
# 3828   2582        2          1     Urbano           2021  272727.883936
# 38124  1872        3          3     Urbano           2021  180881.954462
# 38098  2124        5          1   Subúrbio           2021  288309.840655
# ...     ...      ...        ...        ...            ...            ...
# 11041  2840        5          1      Rural           1950  279761.345082
# 47954  2255        4          2   Subúrbio           1950  235916.370885
# 655    1093        5          3      Rural           1950  118967.691915
# 39553  2119        5          2   Subúrbio           1950  203004.867479
# 24051  1815        3          1   Subúrbio           1950  185279.808332
#
# [50000 rows x 6 columns]

# %%
#Concatenar

# %%
sme1=pd.read_excel('Dataset - Saude Mental Estudantes.xlsx', sheet_name='Dataset - Saude Mental 1')
sme1.head()
# Out:
#    Gênero  Idade       Curso  Ano atual de estudo Nota escolar
# 0  Female     18  Engenharia                    1  3.00 - 3.49
# 1    Male     21      Letras                    2  3.00 - 3.49
# 2    Male     19          TI                    1  3.00 - 3.49
# 3  Female     22     Direito                    3  3.00 - 3.49
# 4    Male     23  Matemática                    4  3.00 - 3.49

# %%
sme2=pd.read_excel('Dataset - Saude Mental Estudantes.xlsx', sheet_name='Dataset - Saude Mental 2')
sme2.head(15)
# Out:
#     Gênero  Idade             Curso  Ano atual de estudo Nota escolar
# 0   Female     23            Letras                    1  2.50 - 2.99
# 1   Female     18      Data Science                    2  3.50 - 4.00
# 2   Female     19       Biomedicina                    3  3.00 - 3.49
# 3   Female     20        Engenharia                    3  3.00 - 3.49
# 4   Female     19      Data Science                    1  3.50 - 4.00
# 5     Male     21      Data Science                    1  3.00 - 3.49
# 6     Male     23  Ciências Humanas                    3  3.50 - 4.00
# 7   Female     20          Economia                    3  3.00 - 3.49
# 8   Female     18      Data Science                    1  3.50 - 4.00
# 9   Female     23          Economia                    1  3.00 - 3.49
# 10  Female     18                TI                    3  3.00 - 3.49
# 11  Female     19      Data Science                    1  3.50 - 4.00
# 12  Female     18                TI                    1  3.50 - 4.00
# 13  Female     24        Engenharia                    1  3.50 - 4.00
# 14  Female     24        Engenharia                    1  3.50 - 4.00

# %%
sme3=pd.read_excel('Dataset - Saude Mental Estudantes.xlsx', sheet_name='Dataset - Saude Mental 3')
sme3.tail(10)
# Out:
#     Casado? Depressão? Ansiedade? Ataque de pânico?  \
# 91      Não        Não        Sim               Não
# 92      Sim        Sim        Não               Não
# 93      Não        Sim        Não               Não
# 94      Não        Não        Não               Sim
# 95      Não        Não        Não               Não
# 96      Não        Não        Sim               Não
# 97      Não        Sim        Sim               Não
# 98      Sim        Sim        Não               Sim
# 99      Não        Não        Não               Não
# 100     Não        Não        Não               Não
#
#     Já consultou um especialista?
# 91                            Não
# 92                            Não
# 93                            Não
# 94                            Não
# 95                            Não
# 96                            Não
# 97                            Não
# 98                            Não
# 99                            Não
# 100                           Não

# %%
print(pd.concat([sme1,sme2]))
print(pd.concat([sme1,sme2]).index.value_counts().sort_index())
# Out:
#     Gênero  Idade         Curso  Ano atual de estudo Nota escolar
# 0   Female     18    Engenharia                    1  3.00 - 3.49
# 1     Male     21        Letras                    2  3.00 - 3.49
# 2     Male     19            TI                    1  3.00 - 3.49
# 3   Female     22       Direito                    3  3.00 - 3.49
# 4     Male     23    Matemática                    4  3.00 - 3.49
# ..     ...    ...           ...                  ...          ...
# 46  Female     21  Data Science                    1  3.50 - 4.00
# 47    Male     18    Engenharia                    2  3.00 - 3.49
# 48  Female     19    Enfermagem                    3  3.50 - 4.00
# 49  Female     23     Pedagogia                    4  3.50 - 4.00
# 50    Male     20   Biomedicina                    2  3.00 - 3.49
#
# [101 rows x 5 columns]
# 0     2
# 1     2
# 2     2
# 3     2
# 4     2
# 5     2
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# 16    2
# 17    2
# 18    2
# 19    2
# 20    2
# 21    2
# 22    2
# 23    2
# 24    2
# 25    2
# 26    2
# 27    2
# 28    2
# 29    2
# 30    2
# 31    2
# 32    2
# 33    2
# 34    2
# 35    2
# 36    2
# 37    2
# 38    2
# 39    2
# 40    2
# 41    2
# 42    2
# 43    2
# 44    2
# 45    2
# 46    2
# 47    2
# 48    2
# 49    2
# 50    1
# Name: count, dtype: int64

# %%
sme_full=pd.concat([sme1,sme2], ignore_index=True)
print(sme_full)
print(sme_full.index.value_counts())
# Out:
#      Gênero  Idade         Curso  Ano atual de estudo Nota escolar
# 0    Female     18    Engenharia                    1  3.00 - 3.49
# 1      Male     21        Letras                    2  3.00 - 3.49
# 2      Male     19            TI                    1  3.00 - 3.49
# 3    Female     22       Direito                    3  3.00 - 3.49
# 4      Male     23    Matemática                    4  3.00 - 3.49
# ..      ...    ...           ...                  ...          ...
# 96   Female     21  Data Science                    1  3.50 - 4.00
# 97     Male     18    Engenharia                    2  3.00 - 3.49
# 98   Female     19    Enfermagem                    3  3.50 - 4.00
# 99   Female     23     Pedagogia                    4  3.50 - 4.00
# 100    Male     20   Biomedicina                    2  3.00 - 3.49
#
# [101 rows x 5 columns]
# 0      1
# 64     1
# 74     1
# 73     1
# 72     1
#       ..
# 31     1
# 30     1
# 29     1
# 28     1
# 100    1
# Name: count, Length: 101, dtype: int64

# %%
pd.concat([sme_full,sme3])
# Out:
#      Gênero  Idade       Curso  Ano atual de estudo Nota escolar Casado?  \
# 0    Female   18.0  Engenharia                  1.0  3.00 - 3.49     NaN
# 1      Male   21.0      Letras                  2.0  3.00 - 3.49     NaN
# 2      Male   19.0          TI                  1.0  3.00 - 3.49     NaN
# 3    Female   22.0     Direito                  3.0  3.00 - 3.49     NaN
# 4      Male   23.0  Matemática                  4.0  3.00 - 3.49     NaN
# ..      ...    ...         ...                  ...          ...     ...
# 96      NaN    NaN         NaN                  NaN          NaN     Não
# 97      NaN    NaN         NaN                  NaN          NaN     Não
# 98      NaN    NaN         NaN                  NaN          NaN     Sim
# 99      NaN    NaN         NaN                  NaN          NaN     Não
# 100     NaN    NaN         NaN                  NaN          NaN     Não
#
#     Depressão? Ansiedade? Ataque de pânico? Já consultou um especialista?
# 0          NaN        NaN               NaN                           NaN
# 1          NaN        NaN               NaN                           NaN
# 2          NaN        NaN               NaN                           NaN
# 3          NaN        NaN               NaN                           NaN
# 4          NaN        NaN               NaN                           NaN
# ..         ...        ...               ...                           ...
# 96         Não        Sim               Não                           Não
# 97         Sim        Sim               Não                           Não
# 98         Sim        Não               Sim                           Não
# 99         Não        Não               Não                           Não
# 100        Não        Não               Não                           Não
#
# [202 rows x 10 columns]

# %%
sme_full=pd.concat([sme_full,sme3], axis=1)
sme_full
# Out:
#      Gênero  Idade         Curso  Ano atual de estudo Nota escolar Casado?  \
# 0    Female     18    Engenharia                    1  3.00 - 3.49     Não
# 1      Male     21        Letras                    2  3.00 - 3.49     Não
# 2      Male     19            TI                    1  3.00 - 3.49     Não
# 3    Female     22       Direito                    3  3.00 - 3.49     Sim
# 4      Male     23    Matemática                    4  3.00 - 3.49     Não
# ..      ...    ...           ...                  ...          ...     ...
# 96   Female     21  Data Science                    1  3.50 - 4.00     Não
# 97     Male     18    Engenharia                    2  3.00 - 3.49     Não
# 98   Female     19    Enfermagem                    3  3.50 - 4.00     Sim
# 99   Female     23     Pedagogia                    4  3.50 - 4.00     Não
# 100    Male     20   Biomedicina                    2  3.00 - 3.49     Não
#
#     Depressão? Ansiedade? Ataque de pânico? Já consultou um especialista?
# 0          Sim        Não               Sim                           Não
# 1          Não        Sim               Não                           Não
# 2          Sim        Sim               Sim                           Não
# 3          Sim        Não               Não                           Não
# 4          Não        Não               Não                           Não
# ..         ...        ...               ...                           ...
# 96         Não        Sim               Não                           Não
# 97         Sim        Sim               Não                           Não
# 98         Sim        Não               Sim                           Não
# 99         Não        Não               Não                           Não
# 100        Não        Não               Não                           Não
#
# [101 rows x 10 columns]

# %%
sme_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 10 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Gênero                         101 non-null    object
#  1   Idade                          101 non-null    int64
#  2   Curso                          101 non-null    object
#  3   Ano atual de estudo            101 non-null    int64
#  4   Nota escolar                   101 non-null    object
#  5   Casado?                        101 non-null    object
#  6   Depressão?                     101 non-null    object
#  7   Ansiedade?                     101 non-null    object
#  8   Ataque de pânico?              101 non-null    object
#  9   Já consultou um especialista?  101 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 8.0+ KB

# %%
queijos=pd.read_csv('Dataset - cheeses.csv')
queijos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cheese   301 non-null    object
#  1   url      301 non-null    object
#  2   milk     295 non-null    object
#  3   country  300 non-null    object
#  4   region   227 non-null    object
# dtypes: object(5)
# memory usage: 11.9+ KB

# %%
queijos_detalhes=pd.read_csv('Dataset - cheese_details.csv')
queijos_detalhes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 358 entries, 0 to 357
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              358 non-null    object
#  1   family           148 non-null    object
#  2   type             355 non-null    object
#  3   fat_content      65 non-null     object
#  4   calcium_content  5 non-null      object
#  5   texture          338 non-null    object
#  6   rind             288 non-null    object
#  7   color            313 non-null    object
#  8   flavor           330 non-null    object
#  9   aroma            294 non-null    object
#  10  vegetarian       227 non-null    object
#  11  vegan            227 non-null    object
#  12  synonyms         80 non-null     object
#  13  alt_spellings    27 non-null     object
#  14  producers        240 non-null    object
# dtypes: object(15)
# memory usage: 42.1+ KB

# %%
#merge
pd.merge(queijos, queijos_detalhes, how='left', on=['url'])
# Out:
#                                     cheese  \
# 0                                Maredsous
# 1                             La Bonaparte
# 2                   Pecorino Boccondilatte
# 3    Brusselae Kaas (Fromage de Bruxelles)
# 4                          Alpe di Frabosa
# ..                                     ...
# 296                         Sarró de Cabra
# 297                               Acapella
# 298                           Les Calendos
# 299              Classics Fresh Mozzarella
# 300                              Swaledale
#
#                                                    url   milk        country  \
# 0                    https://www.cheese.com/maredsous/    cow        Belgium
# 1                 https://www.cheese.com/la-bonaparte/    cow         Canada
# 2       https://www.cheese.com/pecorino-boccondilatte/  sheep          Italy
# 3    https://www.cheese.com/brusselae-kaas-fromage-...    cow        Belgium
# 4              https://www.cheese.com/alpe-di-frabosa/    cow          Italy
# ..                                                 ...    ...            ...
# 296             https://www.cheese.com/sarro-de-cabra/   goat          Spain
# 297                   https://www.cheese.com/acapella/   goat  United States
# 298               https://www.cheese.com/les-calendos/    cow         Canada
# 299  https://www.cheese.com/classics-fresh-mozzarella/    cow  United States
# 300                  https://www.cheese.com/swaledale/  sheep        England
#
#                          region      family                type fat_content  \
# 0                           NaN         NaN                soft         NaN
# 1                        Quebec        Brie  soft, soft-ripened         28%
# 2                Emilia-Romagna    Pecorino  semi-hard, artisan         NaN
# 3                           NaN         NaN       soft, artisan         NaN
# 4                           NaN         NaN           semi-soft         NaN
# ..                          ...         ...                 ...         ...
# 296                   Barcelona         NaN  semi-soft, artisan         NaN
# 297                  California         NaN  soft, soft-ripened         NaN
# 298                      Quebec   Camembert  soft, soft-ripened         NaN
# 299                   Wisconsin  Mozzarella        soft, brined         NaN
# 300  Swaledale, North Yorkshire         NaN                hard         NaN
#
#     calcium_content                                         texture  \
# 0               NaN                                             NaN
# 1               NaN              creamy, soft, soft-ripened, supple
# 2               NaN                                         crumbly
# 3               NaN                                          smooth
# 4               NaN                                             NaN
# ..              ...                                             ...
# 296             NaN                                         buttery
# 297             NaN                                             NaN
# 298             NaN                          creamy, smooth, supple
# 299             NaN  creamy, elastic, smooth, soft, stringy, supple
# 300             NaN                                       semi firm
#
#               rind        color                      flavor            aroma  \
# 0              NaN          NaN                         NaN              NaN
# 1           bloomy        cream         creamy, mild, milky      fresh, mild
# 2          natural        white               subtle, sweet       pronounced
# 3           washed  pale yellow                salty, sharp           strong
# 4              NaN          NaN                      bitter  milky, mushroom
# ..             ...          ...                         ...              ...
# 296  cloth wrapped        white      citrusy, strong, tangy      mild, sweet
# 297            NaN          NaN                     buttery    fresh, herbal
# 298         bloomy        cream       creamy, full-flavored              NaN
# 299       rindless        white  acidic, mild, milky, spicy            fresh
# 300            NaN       yellow               smooth, sweet           floral
#
#     vegetarian  vegan                                          synonyms  \
# 0        False  False                                               NaN
# 1          NaN    NaN                                               NaN
# 2          NaN    NaN                                               NaN
# 3        False  False                                               NaN
# 4        False  False                                               NaN
# ..         ...    ...                                               ...
# 296        NaN    NaN                                             Sarro
# 297      False  False                                               NaN
# 298        NaN    NaN                                               NaN
# 299       True  False  perline, ciliegine, ovoline, marinated ciliegine
# 300       True  False                            Swaledale Sheep Cheese
#
#     alt_spellings                          producers
# 0             NaN                                NaN
# 1             NaN  La Maison Alexis de Portneuf Inc.
# 2             NaN                    Romaniae Terrae
# 3             NaN                                NaN
# 4             NaN                                NaN
# ..            ...                                ...
# 296           NaN               Formatgeries Montbrú
# 297           NaN                                NaN
# 298           NaN  La Maison Alexis de Portneuf Inc.
# 299           NaN    Crave Brothers Farmstead Cheese
# 300           NaN                                NaN
#
# [301 rows x 19 columns]

# %%
queijos.merge(queijos_detalhes, how='left', on='url')
# Out:
#                                     cheese  \
# 0                                Maredsous
# 1                             La Bonaparte
# 2                   Pecorino Boccondilatte
# 3    Brusselae Kaas (Fromage de Bruxelles)
# 4                          Alpe di Frabosa
# ..                                     ...
# 296                         Sarró de Cabra
# 297                               Acapella
# 298                           Les Calendos
# 299              Classics Fresh Mozzarella
# 300                              Swaledale
#
#                                                    url   milk        country  \
# 0                    https://www.cheese.com/maredsous/    cow        Belgium
# 1                 https://www.cheese.com/la-bonaparte/    cow         Canada
# 2       https://www.cheese.com/pecorino-boccondilatte/  sheep          Italy
# 3    https://www.cheese.com/brusselae-kaas-fromage-...    cow        Belgium
# 4              https://www.cheese.com/alpe-di-frabosa/    cow          Italy
# ..                                                 ...    ...            ...
# 296             https://www.cheese.com/sarro-de-cabra/   goat          Spain
# 297                   https://www.cheese.com/acapella/   goat  United States
# 298               https://www.cheese.com/les-calendos/    cow         Canada
# 299  https://www.cheese.com/classics-fresh-mozzarella/    cow  United States
# 300                  https://www.cheese.com/swaledale/  sheep        England
#
#                          region      family                type fat_content  \
# 0                           NaN         NaN                soft         NaN
# 1                        Quebec        Brie  soft, soft-ripened         28%
# 2                Emilia-Romagna    Pecorino  semi-hard, artisan         NaN
# 3                           NaN         NaN       soft, artisan         NaN
# 4                           NaN         NaN           semi-soft         NaN
# ..                          ...         ...                 ...         ...
# 296                   Barcelona         NaN  semi-soft, artisan         NaN
# 297                  California         NaN  soft, soft-ripened         NaN
# 298                      Quebec   Camembert  soft, soft-ripened         NaN
# 299                   Wisconsin  Mozzarella        soft, brined         NaN
# 300  Swaledale, North Yorkshire         NaN                hard         NaN
#
#     calcium_content                                         texture  \
# 0               NaN                                             NaN
# 1               NaN              creamy, soft, soft-ripened, supple
# 2               NaN                                         crumbly
# 3               NaN                                          smooth
# 4               NaN                                             NaN
# ..              ...                                             ...
# 296             NaN                                         buttery
# 297             NaN                                             NaN
# 298             NaN                          creamy, smooth, supple
# 299             NaN  creamy, elastic, smooth, soft, stringy, supple
# 300             NaN                                       semi firm
#
#               rind        color                      flavor            aroma  \
# 0              NaN          NaN                         NaN              NaN
# 1           bloomy        cream         creamy, mild, milky      fresh, mild
# 2          natural        white               subtle, sweet       pronounced
# 3           washed  pale yellow                salty, sharp           strong
# 4              NaN          NaN                      bitter  milky, mushroom
# ..             ...          ...                         ...              ...
# 296  cloth wrapped        white      citrusy, strong, tangy      mild, sweet
# 297            NaN          NaN                     buttery    fresh, herbal
# 298         bloomy        cream       creamy, full-flavored              NaN
# 299       rindless        white  acidic, mild, milky, spicy            fresh
# 300            NaN       yellow               smooth, sweet           floral
#
#     vegetarian  vegan                                          synonyms  \
# 0        False  False                                               NaN
# 1          NaN    NaN                                               NaN
# 2          NaN    NaN                                               NaN
# 3        False  False                                               NaN
# 4        False  False                                               NaN
# ..         ...    ...                                               ...
# 296        NaN    NaN                                             Sarro
# 297      False  False                                               NaN
# 298        NaN    NaN                                               NaN
# 299       True  False  perline, ciliegine, ovoline, marinated ciliegine
# 300       True  False                            Swaledale Sheep Cheese
#
#     alt_spellings                          producers
# 0             NaN                                NaN
# 1             NaN  La Maison Alexis de Portneuf Inc.
# 2             NaN                    Romaniae Terrae
# 3             NaN                                NaN
# 4             NaN                                NaN
# ..            ...                                ...
# 296           NaN               Formatgeries Montbrú
# 297           NaN                                NaN
# 298           NaN  La Maison Alexis de Portneuf Inc.
# 299           NaN    Crave Brothers Farmstead Cheese
# 300           NaN                                NaN
#
# [301 rows x 19 columns]

# %%
queijos.merge(queijos_detalhes, how='right', on='url')
# Out:
#                                     cheese  \
# 0                                Maredsous
# 1                             La Bonaparte
# 2                   Pecorino Boccondilatte
# 3    Brusselae Kaas (Fromage de Bruxelles)
# 4                          Alpe di Frabosa
# ..                                     ...
# 353                                    NaN
# 354                                    NaN
# 355                                    NaN
# 356                                    NaN
# 357                                    NaN
#
#                                                    url   milk  country  \
# 0                    https://www.cheese.com/maredsous/    cow  Belgium
# 1                 https://www.cheese.com/la-bonaparte/    cow   Canada
# 2       https://www.cheese.com/pecorino-boccondilatte/  sheep    Italy
# 3    https://www.cheese.com/brusselae-kaas-fromage-...    cow  Belgium
# 4              https://www.cheese.com/alpe-di-frabosa/    cow    Italy
# ..                                                 ...    ...      ...
# 353     https://www.cheese.com/amarelo-de-beira-baixa/    NaN      NaN
# 354                 https://www.cheese.com/cap-cressy/    NaN      NaN
# 355                   https://www.cheese.com/montasio/    NaN      NaN
# 356            https://www.cheese.com/cuor-di-burrata/    NaN      NaN
# 357                     https://www.cheese.com/basajo/    NaN      NaN
#
#              region    family                               type fat_content  \
# 0               NaN       NaN                               soft         NaN
# 1            Quebec      Brie                 soft, soft-ripened         28%
# 2    Emilia-Romagna  Pecorino                 semi-hard, artisan         NaN
# 3               NaN       NaN                      soft, artisan         NaN
# 4               NaN       NaN                          semi-soft         NaN
# ..              ...       ...                                ...         ...
# 353             NaN       NaN                 semi-firm, artisan      45-60%
# 354             NaN       NaN  semi-hard, artisan, smear-ripened         NaN
# 355             NaN       NaN                          semi-firm         NaN
# 356             NaN       NaN                               soft         NaN
# 357             NaN      Blue             semi-soft, blue-veined         NaN
#
#     calcium_content                             texture     rind        color  \
# 0               NaN                                 NaN      NaN          NaN
# 1               NaN  creamy, soft, soft-ripened, supple   bloomy        cream
# 2               NaN                             crumbly  natural        white
# 3               NaN                              smooth   washed  pale yellow
# 4               NaN                                 NaN      NaN          NaN
# ..              ...                                 ...      ...          ...
# 353             NaN                                 NaN      NaN       yellow
# 354             NaN                      compact, dense   washed  pale yellow
# 355             NaN                              creamy      NaN          NaN
# 356             NaN                      creamy, smooth      NaN        white
# 357             NaN                              creamy      NaN          NaN
#
#                     flavor                 aroma vegetarian  vegan  \
# 0                      NaN                   NaN      False  False
# 1      creamy, mild, milky           fresh, mild        NaN    NaN
# 2            subtle, sweet            pronounced        NaN    NaN
# 3             salty, sharp                strong      False  False
# 4                   bitter       milky, mushroom      False  False
# ..                     ...                   ...        ...    ...
# 353                 acidic                   NaN      False  False
# 354  mellow, savory, sweet                lactic        NaN    NaN
# 355           mild, smooth    aromatic, pleasant      False  False
# 356  buttery, milky, sweet  fresh, herbal, nutty      False  False
# 357                  sweet                fruity      False  False
#
#                                               synonyms alt_spellings  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 353  Amarelo da Beira Baixa Cheese (DOP), Queijo am...           NaN
# 354                                                NaN           NaN
# 355          Montasio Mitica® DOP, Montasio Mitica DOP           NaN
# 356                                                NaN           NaN
# 357                                                NaN           NaN
#
#                              producers
# 0                                  NaN
# 1    La Maison Alexis de Portneuf Inc.
# 2                      Romaniae Terrae
# 3                                  NaN
# 4                                  NaN
# ..                                 ...
# 353                                NaN
# 354          Fifth Town Artisan Cheese
# 355                                NaN
# 356                        Casa Madaio
# 357                                NaN
#
# [358 rows x 19 columns]

# %%
queijos.merge(queijos_detalhes, how='outer', on='url')
# Out:
#                               cheese  \
# 0                   Abbaye de Belval
# 1                           Acapella
# 2    Affineur Walo Rotwein Sennechäs
# 3                      Afuega'l Pitu
# 4         Aged Cashew & Dulse Cheese
# ..                               ...
# 353                  Abbaye de Tamié
# 354              Pecorino Toscanello
# 355                  MouCo Truffello
# 356                  Brick Lane Bree
# 357                     Brixton Blue
#
#                                                    url         milk  \
# 0             https://www.cheese.com/abbaye-de-belval/          cow
# 1                     https://www.cheese.com/acapella/         goat
# 2    https://www.cheese.com/affineur-walo-rotwein-s...          cow
# 3                 https://www.cheese.com/afuegal-pitu/          cow
# 4     https://www.cheese.com/aged-cashew-dulse-cheese/          NaN
# ..                                                 ...          ...
# 353                      https://www.cheese.com/tamie/          cow
# 354                 https://www.cheese.com/toscanello/        sheep
# 355                  https://www.cheese.com/truffello/          cow
# 356  https://www.cheese.com/vegan-brick-lane-bree-c...  plant-based
# 357  https://www.cheese.com/vegan-brixton-blue-cheese/  plant-based
#
#             country       region        family                         type  \
# 0            France          NaN           NaN                    semi-hard
# 1     United States   California           NaN           soft, soft-ripened
# 2       Switzerland          NaN  Swiss Cheese                hard, artisan
# 3             Spain     Asturias           NaN                soft, artisan
# 4     United States  Brooklyn NY           NaN                firm, artisan
# ..              ...          ...           ...                          ...
# 353          France       Savoie           NaN                soft, artisan
# 354           Italy      Tuscany      Pecorino                    semi-hard
# 355   United States     Colorado           NaN  soft, artisan, soft-ripened
# 356  United Kingdom          NaN           NaN                         soft
# 357  United Kingdom          NaN           NaN                    semi-firm
#
#     fat_content calcium_content                          texture  \
# 0        40-46%             NaN                          elastic
# 1           NaN             NaN                              NaN
# 2           NaN             NaN                           smooth
# 3           NaN             NaN                           smooth
# 4           NaN             NaN                 firm, spreadable
# ..          ...             ...                              ...
# 353         NaN             NaN             creamy, open, smooth
# 354         NaN             NaN                   creamy, smooth
# 355         12%             NaN                     creamy, soft
# 356         NaN             NaN     buttery, creamy, gooey, soft
# 357         NaN             NaN  creamy, semi firm, soft-ripened
#
#               rind        color                                        flavor  \
# 0           washed        ivory                                           NaN
# 1              NaN          NaN                                       buttery
# 2           washed        cream                     creamy, pronounced, spicy
# 3    cloth wrapped          NaN                                 spicy, strong
# 4              NaN        brown                               creamy, oceanic
# ..             ...          ...                                           ...
# 353         washed        white                                 fruity, nutty
# 354            NaN  pale yellow                                          mild
# 355         washed        white                       buttery, creamy, earthy
# 356   mold ripened        cream                      buttery, mild, mushroomy
# 357   mold ripened         blue  creamy, full-flavored, piquant, tangy, umami
#
#                                   aroma vegetarian  vegan  \
# 0                              aromatic      False  False
# 1                         fresh, herbal      False  False
# 2                          rich, strong      False  False
# 3                                   NaN      False  False
# 4                                  rich       True  False
# ..                                  ...        ...    ...
# 353                   perfumed, pungent      False  False
# 354                               nutty      False  False
# 355                      earthy, fruity        NaN    NaN
# 356             buttery, mild, mushroom       True   True
# 357  earthy, fermented, pungent, strong       True   True
#
#                                               synonyms  \
# 0                                                  NaN
# 1                                                  NaN
# 2                        Affineur Walo Red Wine Farmer
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 353                                                NaN
# 354  Pecorino Toscano, Pecorino Toscano DOP, Tuscan...
# 355                                          Truffello
# 356                                                NaN
# 357                                                NaN
#
#                                  alt_spellings                producers
# 0                                          NaN                      NaN
# 1                                          NaN                      NaN
# 2                                          NaN     Walo von Mühlenen AG
# 3                                          NaN                      NaN
# 4                                          NaN  Dr. Cow Tree Nut Cheese
# ..                                         ...                      ...
# 353  Tamié, Trappiste de Tamie, Abbey of Tamie                      NaN
# 354                                        NaN                      NaN
# 355                                        NaN     MouCo Cheese Company
# 356                                        NaN           La Fauxmagerie
# 357                                        NaN           La Fauxmagerie
#
# [358 rows x 19 columns]

# %%
queijos.merge(queijos_detalhes, how='inner', on='url')
# Out:
#                                     cheese  \
# 0                                Maredsous
# 1                             La Bonaparte
# 2                   Pecorino Boccondilatte
# 3    Brusselae Kaas (Fromage de Bruxelles)
# 4                          Alpe di Frabosa
# ..                                     ...
# 296                         Sarró de Cabra
# 297                               Acapella
# 298                           Les Calendos
# 299              Classics Fresh Mozzarella
# 300                              Swaledale
#
#                                                    url   milk        country  \
# 0                    https://www.cheese.com/maredsous/    cow        Belgium
# 1                 https://www.cheese.com/la-bonaparte/    cow         Canada
# 2       https://www.cheese.com/pecorino-boccondilatte/  sheep          Italy
# 3    https://www.cheese.com/brusselae-kaas-fromage-...    cow        Belgium
# 4              https://www.cheese.com/alpe-di-frabosa/    cow          Italy
# ..                                                 ...    ...            ...
# 296             https://www.cheese.com/sarro-de-cabra/   goat          Spain
# 297                   https://www.cheese.com/acapella/   goat  United States
# 298               https://www.cheese.com/les-calendos/    cow         Canada
# 299  https://www.cheese.com/classics-fresh-mozzarella/    cow  United States
# 300                  https://www.cheese.com/swaledale/  sheep        England
#
#                          region      family                type fat_content  \
# 0                           NaN         NaN                soft         NaN
# 1                        Quebec        Brie  soft, soft-ripened         28%
# 2                Emilia-Romagna    Pecorino  semi-hard, artisan         NaN
# 3                           NaN         NaN       soft, artisan         NaN
# 4                           NaN         NaN           semi-soft         NaN
# ..                          ...         ...                 ...         ...
# 296                   Barcelona         NaN  semi-soft, artisan         NaN
# 297                  California         NaN  soft, soft-ripened         NaN
# 298                      Quebec   Camembert  soft, soft-ripened         NaN
# 299                   Wisconsin  Mozzarella        soft, brined         NaN
# 300  Swaledale, North Yorkshire         NaN                hard         NaN
#
#     calcium_content                                         texture  \
# 0               NaN                                             NaN
# 1               NaN              creamy, soft, soft-ripened, supple
# 2               NaN                                         crumbly
# 3               NaN                                          smooth
# 4               NaN                                             NaN
# ..              ...                                             ...
# 296             NaN                                         buttery
# 297             NaN                                             NaN
# 298             NaN                          creamy, smooth, supple
# 299             NaN  creamy, elastic, smooth, soft, stringy, supple
# 300             NaN                                       semi firm
#
#               rind        color                      flavor            aroma  \
# 0              NaN          NaN                         NaN              NaN
# 1           bloomy        cream         creamy, mild, milky      fresh, mild
# 2          natural        white               subtle, sweet       pronounced
# 3           washed  pale yellow                salty, sharp           strong
# 4              NaN          NaN                      bitter  milky, mushroom
# ..             ...          ...                         ...              ...
# 296  cloth wrapped        white      citrusy, strong, tangy      mild, sweet
# 297            NaN          NaN                     buttery    fresh, herbal
# 298         bloomy        cream       creamy, full-flavored              NaN
# 299       rindless        white  acidic, mild, milky, spicy            fresh
# 300            NaN       yellow               smooth, sweet           floral
#
#     vegetarian  vegan                                          synonyms  \
# 0        False  False                                               NaN
# 1          NaN    NaN                                               NaN
# 2          NaN    NaN                                               NaN
# 3        False  False                                               NaN
# 4        False  False                                               NaN
# ..         ...    ...                                               ...
# 296        NaN    NaN                                             Sarro
# 297      False  False                                               NaN
# 298        NaN    NaN                                               NaN
# 299       True  False  perline, ciliegine, ovoline, marinated ciliegine
# 300       True  False                            Swaledale Sheep Cheese
#
#     alt_spellings                          producers
# 0             NaN                                NaN
# 1             NaN  La Maison Alexis de Portneuf Inc.
# 2             NaN                    Romaniae Terrae
# 3             NaN                                NaN
# 4             NaN                                NaN
# ..            ...                                ...
# 296           NaN               Formatgeries Montbrú
# 297           NaN                                NaN
# 298           NaN  La Maison Alexis de Portneuf Inc.
# 299           NaN    Crave Brothers Farmstead Cheese
# 300           NaN                                NaN
#
# [301 rows x 19 columns]
