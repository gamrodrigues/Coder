# %%
import pandas as pd
import sqlite3

# %%
## Criando DataFrame de produtos
df_produtos = pd.DataFrame({'nome': ['ovos', 'manteiga', 'peixe'],
                   'valor': [10, 20, 30]})
df_produtos
# Out:
#        nome  valor
# 0      ovos     10
# 1  manteiga     20
# 2     peixe     30

# %%
## Exportando a tabela produtos como um banco de dados
# Conectar ao banco de dados
conn = sqlite3.connect('coderhouse.db')

# Escrever o DataFrame na tabela 'produtos'
df_produtos.to_sql('produtos', conn, if_exists='replace', index=False)

# Fechar a conexão com o banco de dados
conn.close()

# %%
##Importanto a tabela produtos de um banco de dados
conn = sqlite3.connect('coderhouse.db')

# Executar uma consulta SELECT na tabela 'produtos' e converter em um DataFrame
query = "SELECT * FROM produtos"
df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#        nome  valor
# 0      ovos     10
# 1  manteiga     20
# 2     peixe     30

# %%
##Verificando quais tabelas existem no esquema sqlite master de um banco de dados
conn = sqlite3.connect('coderhouse.db')

# Executar uma consulta que retorna as informações do esquema do banco de dados
query = "SELECT name FROM sqlite_master WHERE type='table'"
schema = pd.read_sql_query(query, conn)

# Imprimir o DataFrame com os nomes das tabelas
print(schema)

conn.close()
# Out:
#        name
# 0  produtos

# %%
#importando o .csv de poluição atmosférica
poluicao_atmosferica=pd.read_csv('Dataset - Poluição atmosférica.csv', sep=';').dropna(axis=1)
poluicao_atmosferica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1106 entries, 0 to 1105
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Data    1106 non-null   object
#  1   País    1106 non-null   object
#  2   Status  1106 non-null   object
#  3   IQA     1106 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 34.7+ KB

# %%
## Exportando a tabela poluição atmosférica como um banco de dados
# Conectar ao banco de dados
conn = sqlite3.connect('coderhouse.db')

# Escrever o DataFrame na tabela 'produtos'
poluicao_atmosferica.to_sql('poluicao_atmosferica', conn, if_exists='replace', index=False)

# Fechar a conexão com o banco de dados
conn.close()

# %%
##Verificando quais tabelas existem no esquema sqlite master de um banco de dados
conn = sqlite3.connect('coderhouse.db')

# Executar uma consulta que retorna as informações do esquema do banco de dados
query = "SELECT name FROM sqlite_master WHERE type='table'"
schema = pd.read_sql_query(query, conn)

# Imprimir o DataFrame com os nomes das tabelas
print(schema)

conn.close()
# Out:
#                    name
# 0              produtos
# 1  poluicao_atmosferica

# %%
##Importanto a tabela poluição atmosférica de um banco de dados
conn = sqlite3.connect('coderhouse.db')

# Executar uma consulta SELECT na tabela 'produtos' e converter em um DataFrame
query = "SELECT * FROM {}".format(schema.name[1])
df = pd.read_sql(query, conn)
print(df)

conn.close()
# Out:
#             Data        País     Status  IQA
# 0     12/01/2023     Albania        Bom    9
# 1     12/01/2023     Algeria   Moderado   65
# 2     12/01/2023     Andorra        Bom    9
# 3     12/01/2023      Angola        Bom   45
# 4     12/01/2023   Argentina        Bom   19
# ...          ...         ...        ...  ...
# 1101  11/05/2023  Uzbekistan   Moderado   57
# 1102  11/05/2023     Vatican        Bom   50
# 1103  11/05/2023   Venezuela        Bom   17
# 1104  11/05/2023     Vietnam  Modderado   94
# 1105  11/05/2023      Zambia  Modderado   67
#
# [1106 rows x 4 columns]
